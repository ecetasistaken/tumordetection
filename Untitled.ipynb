# %%
import os
from ultralytics import YOLO
import cv2
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# # Training Pretrained YOLOv8s

# %%
model = YOLO(r"yolov8s.pt")
model.train(
    data=r"C:\Users\Hp\Desktop\Dataset\archive (1)\BrainTumorYolov8\data.yaml",
    epochs=15
    , batch=4)
model.save(r"yolov8-tumor.pt")
# Out:
# New https://pypi.org/project/ultralytics/8.3.65 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.38  Python-3.12.1 torch-2.4.1 CPU (Intel Core(TM) i7-8565U 1.80GHz)
# ...

# %% [markdown]
# # Data Distribution

# %%
image_path = r"C:\Users\Hp\tumorproject\runs\detect\train3\labels.jpg"
img = Image.open(image_path)
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# # Results

# %%
image_path = r"C:\Users\Hp\tumorproject\runs\detect\train3\results.png"
img = Image.open(image_path)
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
image_path = r"C:\Users\Hp\tumorproject\runs\detect\train3\confusion_matrix.png"
img = Image.open(image_path)
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image

folder_path = r"C:\Users\Hp\tumorproject\runs\detect\train3"

filter_keyword = "curve"  
file_extension = ".png" 

image_files = [f for f in os.listdir(folder_path) 
    if f.endswith(file_extension) and filter_keyword in f]

for image_file in image_files:
    image_path = os.path.join(folder_path, image_file)
    img = Image.open(image_path)
    
    plt.figure()
    plt.imshow(img)
    plt.title(image_file)
    plt.axis("off")
    plt.show()
